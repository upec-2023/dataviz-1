# %% [markdown]
# <hr style="border-width:2px;border-color:#75DFC1">
# <center><h1>Introduction à la visualisation de données avec Matplotlib</h1></center>
# <center><h2> Subplots et Graphiques emboîtés </h2></center>
# <hr style="border-width:2px;border-color:#75DFC1">

# %%
### Veuillez exécuter cette case avant de commencer l'exercice
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# >Sur une même figure Matplotlib, il est possible d'afficher plusieurs graphiques en grille; grâce à la fonction **`subplot`** qui crée une figure automatiquement et la divise autant qu'on le souhaite.<br>
# La fonction **`subplot`** prend en arguments: le nombre de lignes de la figure (*numrows*) , le nombre de colonnes (*numcols*) et le numéro du graphique sur lequel on souhaite se positionner (compris entre 1 et *numrows* x *numcols*) .
#
# >Les virgules sont optionnelles si $numrows \times numcols <10$. Ainsi `subplot(211)` est identique à `subplot(2, 1, 1)`.
#
# ><span style="color:#09b038; text-decoration : underline"> Exemple : </span>
# > Ecrire `plt.subplot(4,3,2)` en début de cellule crée et partage une figure en 4 x 3 emplacements de graphes (4 lignes et 3 colonnes) et sélectionne le 2ème emplacement pour les instructions graphiques suivantes. <br>
# Pour afficher un graphique sur la case suivante, il suffit d'écrire `plt.subplot(4,3,3)`suivi des fonctions **plt** que l'on souhaite.
#
# <div class="alert alert-success">
# <i class="fa fa-question-circle"></i> &emsp;
# Les numéros des graphes sont comptés par ligne. Le graphe situé sur la deuxième ligne et la troisième colonne, par exemple sera donc le graphe n°6.
# </div>
#
# <div class="alert alert-success">
# <i class="fa fa-question-circle"></i> &emsp;
# Lorsque l'on utilise une fonction de <b>pyplot</b>, une figure se crée automatiquement, au format standard par défaut.<br>
# Il est possible de créer une figure aux dimensions <b>(h,l)</b> grâce à la commande <b>plt.figure( figsize= (h, l) )</b>.
# </div>
#
#
# * Lire le fichier `'sales_data.csv'`.
# * Afficher sur une même figure, de taille (10,10) les quatre graphiques suivant :
#  * Un *barplot* du nombre de ventes du Produit 1.
#  * Un nuage de points du nombre de ventes du produit 2 en fonction du nombre de ventes du produit 1.
#  * Une courbe représentant le nombre de retours d'articles.
#  * Un histogramme représentant le chiffre d'affaire mensuel.
#
# *Note : Vous pourrez utiliser, pour chaque graphique, les formes et couleurs de votre choix.*

# %%
## Insérez votre code ici

# %%
# Out:
#      Month  Product1  Product2  Returns  Turnover
# 0  01-janv       266       355        0     25285
# 1  01-fevr       145       204        6     14255
# 2  01-mars       183       196       11     15225
# 3   01-avr       119       189        5     12670
# 4   01-mai       180       169       13     13905

# %% [markdown]
# > Les méthodes graphiques des Data Frames Pandas ne permettent pas d'afficher directement plusieurs graphiques différents au sein d'une même figure.<br>
# Cependant, il peut être utile de noter que certaines méthodes comme `plot` contiennent le paramètre `subplots` qui s'il vaut `True`, divise la figure en autant de graphique que de variables présentes. Le paramètre `layout` permet de choisir la disposition des cellules que l'on crée.
#
# > Voici un exemple de création de graphiques sur la même figure avec Pandas :

# %%
## Insérez votre code ici

# %% [markdown]
# > Sur **``matplotlib``**, il est également possible d'insérer un graphe à l'intérieur d'un autre, grâce à la fonction **``axes``**. <br>
# Il suffit de lui donner en argument une liste contenant les positions ``x`` et ``y`` du point en bas à gauche du graphe à insérer, (valeurs entre ``0`` et ``1``, indépendamment des axes choisis) , ainsi que les dimensions de ce dernier (largeur et hauteur, entre ``0`` et ``1``).<br>
# Pour plus de visibilité, il est recommandé de donner à cet axe un fond de couleur différente, grâce à l'ajout de l'argument `facecolor`.
# Par exemple, ``plt.axes([.5, 0.6, .2, .2], facecolor='grey')`` crée un graphique avec fond gris dont le point en bas à gauche se situe en abscisse au milieu du graphique actuel , en ordonnée à 60% de hauteur, et dont la largeur et la hauteur représentent 20% de celles du graphique actuel.
#
# <div class="alert alert-success">
# <i class="fa fa-question-circle"></i> &emsp;
#  Dans un souci d'esthétisme, il est préférable de supprimer les graduations des axes des graphiques insérés dans d'autres.
# Les commandes <b>plt.xticks([ ])</b> et <b>plt.yticks([ ])</b> suffisent à supprimer respectivement les axes x et y.
# </div>
#
# * Créer une figure de taille (7,7), contenant le *boxplot* associé au chiffre d'affaire mensuel (*'Turnover'*)
# > On cherche désormais à insérer une deuxième graphe au sein de ce premier :
#
# * Créer un second graphique à la position (0.65, 0.65) et de taille (0.2, 0.15) avec un fond de code couleur `#ffe5c1`.
# * A l'intérieur, tracez l'histogramme de la même variable de code couleur `#FFC575`.
# * Supprimer les axes et donner aux abscisses le label : 'Distribution'.

# %%
## Insérez votre code ici
