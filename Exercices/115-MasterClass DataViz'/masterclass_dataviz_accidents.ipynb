# %% [markdown]
# <hr style="border-width:2px;border-color:#75DFC1">
# <h1 style = "text-align:center" > MasterClass DataViz </h1>
# <h2 style = "text-align:center"> Analyser les accidents de la route de l'année 2016 </h2>
# <hr style="border-width:2px;border-color:#75DFC1">
#
#
# >Lor de cette Masterclass nous travaillerons sur des données provenant d'une plateforme de financement participatif (*Kickstarter*), qui donne la possibilité aux internautes de financer des projets encore au stade d'idée, en réduisant les inconvénients associées aux modes traditionnels d'investissement.
#
#
# > Lors de cette Masterclass, nous allons être chargés par une Compagnie d'Assurance de mener une étude sur les accidents de la route, impliquant ses clients assurés au cours de l'année 2016.
#
# > Dans un but d'analyse et de comparaisons, nous avons accès à des jeux de données publiques concernant les circonstances des accidents de la route avec dommages corporels survenus en France en 2016 , ainsi qu'aux données internes de la compagnie à propos de ses assurés victimes d'accident la même année.
#
# >Le fichier "caracteristiques.csv" contient les principales caractéristiques de chaque accident survenu en France en 2016.
#
# >Le fichier "base_clients.csv" contient des informations sur les clients de la compagnie d'assurance, qui ont été impliqués dans au moins un accident en 2016.
#
# >`Num_Acc` est une variable commune à tous les fichiers, qui identifie chaque accident.
#
# > Une description de toutes les variables des jeux de données est disponible [ici](https://datascientest.fr/train/assets/eval_allianz_3.pdf).
#
# >L'objectif de cette masterclass est d'effectuer une première analyse visuelle des données en notre possession.
#
#
# * Commençons par charger les packages **pandas**, **numpy**, **matplotlib.pyplot**, et **seaborn**.
# * Puis chargeons les jeux de données *'caracteristiques.csv* et *'base_clients.csv'* dans des dataframes nommés respectivement **carac** et **clients**.

# %%
import warnings
warnings.filterwarnings("ignore")
## Insérez votre code ici
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

carac = pd.read_csv("caracteristiques.csv")
clients = pd.read_csv("base_clients.csv")

# %% [markdown]
# >Nous allons commencer par nous intéresser à l'ensemble des accidents corporels de l'année 2016.
#
# * Affichons les premières lignes de **carac**, puis les informations sur chaque variable.

# %%
## Insérez votre code ici

# %%
# Out:
#         Num_Acc  an  mois  jour  hrmn  lum  agg                atm  col  grav  \
# 0  201600000001  16     2     1  1445    1    2      Temps couvert  3.0     2
# 1  201600000002  16     3    16  1800    1    2             Normal  6.0     2
# 2  201600000003  16     7    13  1900    1    1             Normal  6.0     2
# 3  201600000004  16     8    15  1930    2    2  Temps eblouissant  3.0     1
# 4  201600000005  16    12    23  1100    1    2             Normal  3.0     2
#
#    com                  adr gps  lat  long  dep
# 0    5   46, rue Sonneville   M  0.0   0.0   59
# 1    5  1a rue du cimetière   M  0.0   0.0   59
# 2   11                  NaN   M  0.0   0.0   59
# 3  477   52 rue victor hugo   M  0.0   0.0   59
# 4   11     rue Joliot curie   M  0.0   0.0   59
#             Num_Acc       an          mois          jour          hrmn  \
# count  5.943200e+04  59432.0  59432.000000  59432.000000  59432.000000
# ...

# %% [markdown]
# > 4 variables sont décrites comme catégorielles, mais parmis les variables numériques, nombreuses sont celles qui sont également qualitatives.
# > La variable **col** par exemple correspond aux 7 différentes collisions possibles pour un accident.
# * 1 – Deux véhicules - frontale
# * 2 – Deux véhicules – par l’arrière
# * 3 – Deux véhicules – par le coté
# * 4 – Trois véhicules et plus – en chaîne
# * 5 – Trois véhicules et plus - collisions multiples
# * 6 – Autre collision
# * 7 – Sans collision
#
# * Analysons le nombre d'accidents correspondant à chaque type de collision:

# %%
## Insérez votre code ici

# %%
# Out:
# <Axes: xlabel='col', ylabel='count'>

# %% [markdown]
# > Il apparaît que les accidents survenus par collison à deux véhicules et par le côté sont les plus fréquents, après 'Autres' dont on ignore la signification.
#
# > Notre DataFrame contient le jour, le mois et l'année (2016) de chaque accident, il est donc possible d'en extraire la date exacte, afin d'afficher un graphique daté chronologique, ou chaque point correspond à un jour de l'année 2016.
#
# * Pour cela, il faut dans un premier temps créer une variable contenant la date complète pour chaque accident.<br> Puis convertir cette variable en `datetime` et compter le nombre d'occurences pour chaque date.
#
# * Pour pouvoir afficher un graphique chronologique, il faut  ordonner ces valeurs selon les dates en indices.
#
# * Il suffit ensuite d'utiliser la méthode `plot_date()` de *matplotlib*, pour afficher les index et les valeurs qui correspondent aux nombre d'accident pour chaque jour.

# %%
## Insérez votre code ici

# %%
# Out:
# date
# 2016-06-10    263
# 2016-11-30    260
# 2016-10-11    250
# 2016-08-07    247
# 2016-11-18    242
#              ...
# 2016-02-21     99
# 2016-12-31     92
# 2016-12-25     82
# 2016-01-17     81
# 2016-03-28     68
# Name: count, Length: 366, dtype: int64

# %% [markdown]
# > Le graphique nous montre des pics d'accidents importants pour certains jours, et une tendance globale qui montre que certains mois sont plus propices aux accients que d'autres.
#
# * Vérifions ce constat, en affichant le nombre d'accidents par mois.

# %%
## Insérez votre code ici

# %% [markdown]
# > Les mois de Février, Avril et Août sont les mois avec le moins d'accidents corporels enregistrés. Les mois de Novembre et Juillet sont les mois recensant le plus d'accidents.<br>
# > Qu'en est-il des jours de la semaine?
#
# > La méthode `dt.weekday` permet de déterminer le jour de la semaine à partir d'une date au format `datetime`.
# * Comparons le nombre d'accidents pour chaque jour de la semaine au cours de l'année 2016.

# %%
## Insérez votre code ici

# %%
## Insérez votre code ici:

# %% [markdown]
# > La variable *`hrmn`* contient l'heure et les minutes de chaque accident.
#
# * Affichons la distribution de cette variable, en choisissant 24 intervalles, et ajouter les heures séparant la journée sur l'axe des abscisses.

# %%
## Insérez votre code ici

# %%
## Insérez votre code ici

# %% [markdown]
# > Il semble y avoir une grande partie des accidents le matin, et dans la soirée entre 17h et 19h. Logique, puisqu'il s'agit des heures de la journée où l'on observe le plus de circulations.
#
# > Y a-t-il des départements plus intéressés par sécurité routière que d'autres?
#
# * Affichons, côtes à côtes, les 10 départements avec le plus d'accidents, et les 10 avec le moins d'accidents en 2016.

# %%
## Insérez votre code ici

# %% [markdown]
# > La majorité des départements avec le plus d'accidents font partie des départements les plus peuplés de France. La réciproque est aussi vrai pour les départements les moins peuplés.
#
# > Les département d'Outre-Mer ne font parte d'aucun des deux classements, il pourrait être intéressant d'observer en moyenne, combien d'accidents corporels touchent ces départements par mois, par rapport aux départements de métropole.
#
# * Affichons l'évolution du nombre d'accidents moyen par mois et par département pour les Dom-Tom et la métropole.

# %%
## Insérez votre code ici

# %% [markdown]
# > Regardons à présent, où se situent géographiquement les différents accidents ayant lieu en métropole, selon leurs degrés de gravité.
#
# * Exécutez la cellule suivante pour afficher les coordonnées de chaque accident de métropole.

# %%
## Insérez votre code ici

# %% [markdown]
# > La variable *`atm`* distingue les conditions athmospériques des accidents survenus, la variable *`grave`* le niveau de gravité maximum de l'accident, et *'col'* le type de collisions.
#
# * Comment les conditions athmosphériques et le type de collision influent sur la gravité de l'accident?

# %%
## Insérez votre code ici

# %% [markdown]
# > Nous allons à présent nous intéresser à la base de données clients.
#
# * Affichons un aperçu des premières lignes du Dataframe **clients**.

# %%
## Insérez votre code ici

# %%
# Out:
#      ID_Client       Num_Acc  dep_residence  Souscription_Premium+  \
# 0  ID_00015117  201600000009             59                      0
# 1  ID_00019488  201600000010             59                      0
# 2  ID_00011159  201600000011             59                      0
# 3  ID_00019361  201600000024             59                      0
# 4  ID_00016105  201600000025             59                      0
#
#           cout annees_permis  age_v sexe   age
# 0  1273.071553             0    7.0    F  32.0
# 1  1180.182189             0    7.0    H  25.0
# 2   625.490049             9    5.0    H  43.0
# 3   522.757581             9    9.0    F  60.0
# 4   346.974776        +10ans    9.0    F  50.0

# %% [markdown]
# > Quelle part des accidents de la route avec dommages corporels, ceux impliquant les clients de la compagnie d'Assurance représentent-ils?
#
# * Afficher, dans un diagramme circulaire, la part d'accidents impliquant des clients de la compagnie

# %%
## Insérez votre code ici

# %% [markdown]
# > Quel age ont les clients?
#
# * Affichons la distributions de la variable *`age`*.

# %%
## Insérez votre code ici

# %% [markdown]
# > La moyenne d'âge des clients assurés est d'environ 40 ans. La catégorie des 18-25ans est la plus représentée.<br>
# > Le cout annuelle de l'assurance auto pour les clients dépend-il de l'âge?
#
# * Analysons la relation entre les variables *`age`* et *`cout`*, à l'aide d'un nuage de point et d'une courbe de tendance d'ordre 2.

# %%
## Insérez votre code ici

# %% [markdown]
# > Le coût de l'assurance semble décroire avec l'âge du client. Cependant, après la cinquantaine, le coût se stabilise et peut parfois être éventuellement élevé même à un âge avancé. Ceci pourrait s'expliquer par d'autres facteurs comme le type de voiture utilisé ou l'âge de cette dernière.
#
# * Parmis les clients assurés, combien ont souscrit à l'offre 'Premium+'? Comparons la part de clients Premium+ chez les hommes et le femmes.

# %%
## Insérez votre code ici

# %% [markdown]
# > Les femmes ont une proportion un peu plus élevées de souscription à l'offre 'Premium +'.
#
# > Les jeunes ou moins jeunes conducteurs sont-ils plus concernés par les accidents impliquant un décès?
#
# * Affichons un graphique représentant la distribution de l'age des clients, en fonction de la gravité de l'accident.

# %%
## Insérez votre code ici

# %% [markdown]
# > L'age moyen est moins elevé pour les accidents impliquant un décès, mais de manière trop lègère pour être significative.<br>
#
# > Un nombre d'années de permis élevé présume-t-il d'une meilleure conduite?
#
# * Affichons le nombres d'accidents par degré de gravité, en fonction du nombre d'années de permis.

# %%
## Insérez votre code ici

# %% [markdown]
# > Le graphique montre que les clients avec moins de 3 ans de permis ont une plus forte proportion d'accidents entraînant un décès.
#
# > Nous sommes arrivés à la fin de cette *MasterClass*, merci de l'avoir suivi. Vous pouvez bien entendu continuer à explorer les données sous différents angles, à vous de jouer !
